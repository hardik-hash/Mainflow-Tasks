# %% [markdown]
# <a href="https://colab.research.google.com/github/hardik-hash/Mainflow-Tasks/blob/main/MainflowTask2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing pandas library as 'pd'
import pandas as pd

# %%
#Loading the file into pandas dataframe
dataset=pd.read_csv('/content/01.Data Cleaning and Preprocessing.csv')

# %%
#Analyze the  summary of the dataframe
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 324 entries, 0 to 323
# Data columns (total 23 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Observation      324 non-null    object
#  1   Y-Kappa          324 non-null    float64
#  2   ChipRate         319 non-null    float64
#  3   BF-CMratio       307 non-null    float64
#  4   BlowFlow         308 non-null    float64
#  5   ChipLevel4       323 non-null    float64
#  6   T-upperExt-2     322 non-null    float64
#  7   T-lowerExt-2     322 non-null    float64
#  8   UCZAA            299 non-null    float64
#  9   WhiteFlow-4      323 non-null    float64
#  10  AAWhiteSt-4      173 non-null    float64
#  11  AA-Wood-4        323 non-null    float64
#  12  ChipMoisture-4   323 non-null    float64
#  13  SteamFlow-4      323 non-null    float64
#  14  Lower-HeatT-3    322 non-null    float64
#  15  Upper-HeatT-3    322 non-null    float64
# ...

# %%
#All the column names of the dataframe
dataset.columns
# Out:
# Index(['Observation', 'Y-Kappa', 'ChipRate', 'BF-CMratio', 'BlowFlow',
#        'ChipLevel4 ', 'T-upperExt-2 ', 'T-lowerExt-2  ', 'UCZAA',
#        'WhiteFlow-4 ', 'AAWhiteSt-4 ', 'AA-Wood-4  ', 'ChipMoisture-4 ',
#        'SteamFlow-4 ', 'Lower-HeatT-3', 'Upper-HeatT-3 ', 'ChipMass-4 ',
#        'WeakLiquorF ', 'BlackFlow-2 ', 'WeakWashF ', 'SteamHeatF-3 ',
#        'T-Top-Chips-4 ', 'SulphidityL-4 '],
#       dtype='object')

# %%
#The total number of rows in the dataframe
dataset.index
# Out:
# RangeIndex(start=0, stop=324, step=1)

# %%
#Total elements of the dataframe
dataset.size
# Out:
# 7452

# %%
#A quick look or a sample
dataset.head(10)
# Out:
#   Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0    31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1    31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2    31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3    31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4    31-04:00    22.90    15.618      93.244  1334.168      243.131
# 5     1-08:00    14.23    15.350      85.518  1171.604      198.538
# 6     1-09:00    13.49    13.700      98.186  1243.688      116.275
# 7    31-06:00    22.65    14.100      91.887  1307.852      288.989
# 8    31-07:00    22.50    14.233      97.249  1346.900      330.325
# 9    31-08:00    24.70    13.850      96.208  1334.892      362.511
#
#    T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# 0        358.282         329.545  1.443       599.253  ...        67.122
# ...

# %%
#The latest data from the dataframe
dataset.tail(10)
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 314     8-13:00    16.70       NaN         NaN       NaN        0.000
# 315     8-14:00    16.05    13.114         NaN       NaN        0.000
# 316     8-15:00    17.75    11.283         NaN       NaN       41.607
# 317     4-16:00    17.80    16.625      78.367  1276.082      202.744
# 318     4-17:00    18.20    16.283      83.508  1288.104      234.284
# 319    10-16:00    23.75    12.667      93.450  1178.252      276.955
# 320     9-19:00    19.80    12.558      94.352  1184.119      297.071
# 321     9-20:00    23.01    12.550      90.842  1188.517      289.826
# 322     9-21:00    24.32    13.083      88.910  1192.879      318.006
# 323     9-22:00    25.75    13.417      85.451  1186.342      248.312
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# 314        373.867         324.184  1.596       533.538  ...        59.310
# ...

# %%
#Null values in each column
dataset.isna().sum()
# Out:
# Observation          0
# Y-Kappa              0
# ChipRate             5
# BF-CMratio          17
# BlowFlow            16
# ChipLevel4           1
# T-upperExt-2         2
# T-lowerExt-2         2
# UCZAA               25
# WhiteFlow-4          1
# AAWhiteSt-4        151
# AA-Wood-4            1
# ChipMoisture-4       1
# SteamFlow-4          1
# Lower-HeatT-3        2
# Upper-HeatT-3        2
# ChipMass-4           1
# WeakLiquorF          1
# BlackFlow-2          2
# WeakWashF            1
# SteamHeatF-3         2
# T-Top-Chips-4        1
# SulphidityL-4      151
# dtype: int64

# %%
#Null values' presence in each column per row
dataset.isnull()
# Out:
#      Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0          False    False     False       False     False        False
# 1          False    False     False       False     False        False
# 2          False    False     False       False     False        False
# 3          False    False     False       False     False        False
# 4          False    False     False       False     False        False
# ..           ...      ...       ...         ...       ...          ...
# 319        False    False     False       False     False        False
# 320        False    False     False       False     False        False
# 321        False    False     False       False     False        False
# 322        False    False     False       False     False        False
# 323        False    False     False       False     False        False
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %%
#Dropping the rows with null values
new_dataset = dataset.dropna()
new_dataset
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 1      31-01:00    27.60    16.810      79.022  1328.360      341.327
# 3      31-03:00    23.60    16.478      81.011  1334.877      213.527
# 5       1-08:00    14.23    15.350      85.518  1171.604      198.538
# 7      31-06:00    22.65    14.100      91.887  1307.852      288.989
# 9      31-08:00    24.70    13.850      96.208  1334.892      362.511
# ..          ...      ...       ...         ...       ...          ...
# 312    31-10:00    24.40    14.117      85.998  1330.104      394.234
# 317     4-16:00    17.80    16.625      78.367  1276.082      202.744
# 319    10-16:00    23.75    12.667      93.450  1178.252      276.955
# 320     9-19:00    19.80    12.558      94.352  1184.119      297.071
# 322     9-21:00    24.32    13.083      88.910  1192.879      318.006
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %%
print("The dataset length before removing null values is: ", len(dataset))
print("The dataset length after removing null values is: ", len(new_dataset))
print("The number of rows that removed are: ", len(dataset) - len(new_dataset))
# Out:
# The dataset length before removing null values is:  324
# The dataset length after removing null values is:  141
# The number of rows that removed are:  183

# %%
#Filling the null values with "No data collected"
data = dataset.fillna("No data collected")
data
# Out:
#     Observation  Y-Kappa ChipRate BF-CMratio  BlowFlow ChipLevel4   \
# 0      31-00:00    23.10    16.52    121.717  1177.607     169.805
# 1      31-01:00    27.60    16.81     79.022   1328.36     341.327
# 2      31-02:00    23.19   16.709     79.562  1329.407     239.161
# 3      31-03:00    23.60   16.478     81.011  1334.877     213.527
# 4      31-04:00    22.90   15.618     93.244  1334.168     243.131
# ..          ...      ...      ...        ...       ...         ...
# 319    10-16:00    23.75   12.667      93.45  1178.252     276.955
# 320     9-19:00    19.80   12.558     94.352  1184.119     297.071
# 321     9-20:00    23.01    12.55     90.842  1188.517     289.826
# 322     9-21:00    24.32   13.083      88.91  1192.879     318.006
# 323     9-22:00    25.75   13.417     85.451  1186.342     248.312
#
#     T-upperExt-2  T-lowerExt-2                UCZAA WhiteFlow-4   ...  \
# 0         358.282        329.545              1.443      599.253  ...
# ...

# %%
dataset.drop('Observation', axis=1)
# Out:
#      Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   T-upperExt-2   \
# 0      23.10    16.520     121.717  1177.607      169.805        358.282
# 1      27.60    16.810      79.022  1328.360      341.327        351.050
# 2      23.19    16.709      79.562  1329.407      239.161        350.022
# 3      23.60    16.478      81.011  1334.877      213.527        350.938
# 4      22.90    15.618      93.244  1334.168      243.131        351.640
# ..       ...       ...         ...       ...          ...            ...
# 319    23.75    12.667      93.450  1178.252      276.955        347.286
# 320    19.80    12.558      94.352  1184.119      297.071        399.135
# 321    23.01    12.550      90.842  1188.517      289.826        373.633
# 322    24.32    13.083      88.910  1192.879      318.006        364.081
# 323    25.75    13.417      85.451  1186.342      248.312        356.289
#
#      T-lowerExt-2    UCZAA  WhiteFlow-4   AAWhiteSt-4   ...  SteamFlow-4   \
# ...

# %%
new_dataset.describe()
# Out:
#           Y-Kappa    ChipRate  BF-CMratio     BlowFlow  ChipLevel4   \
# count  141.000000  141.000000  141.000000   141.000000   141.000000
# mean    20.780567   14.407277   86.842078  1241.878766   267.190312
# std      3.104667    1.501403    7.447316    72.414829    80.965627
# min     12.170000   10.833000   68.645000   954.092000     0.000000
# 25%     18.500000   13.420000   81.087000  1194.181000   219.669000
# 50%     20.750000   14.375000   86.950000  1276.082000   276.955000
# 75%     23.300000   15.542000   92.142000  1290.006000   332.497000
# max     27.600000   16.817000  114.570000  1334.892000   419.014000
#
#        T-upperExt-2   T-lowerExt-2         UCZAA  WhiteFlow-4   AAWhiteSt-4   \
# count     141.000000      141.000000  141.000000    141.000000    141.000000
# mean      356.841801      324.062270    1.497695    593.977879      6.144872
# std         9.924441        7.850917    0.103568     67.695750      0.080408
# ...

# %%
new_dataset.sum()
# Out:
# Observation        31-01:0031-03:001-08:0031-06:0031-08:0031-10:0...
# Y-Kappa                                                      2930.06
# ChipRate                                                    2031.426
# BF-CMratio                                                 12244.733
# BlowFlow                                                  175104.906
# ChipLevel4                                                 37673.834
# T-upperExt-2                                               50314.694
# T-lowerExt-2                                                45692.78
# UCZAA                                                        211.175
# WhiteFlow-4                                                83750.881
# AAWhiteSt-4                                                  866.427
# AA-Wood-4                                                   2515.484
# ChipMoisture-4                                              6590.415
# SteamFlow-4                                                 9457.234
# ...

# %%
data1  = new_dataset.filter(items=['Y-Kappa', 'UCZAA'])
data1
# Out:
#      Y-Kappa  UCZAA
# 1      27.60  1.549
# 3      23.60  1.604
# 5      14.23  1.436
# 7      22.65  1.468
# 9      24.70  1.515
# ..       ...    ...
# 312    24.40  1.429
# 317    17.80  1.488
# 319    23.75  1.523
# 320    19.80  1.451
# 322    24.32  1.523
#
# [141 rows x 2 columns]

# %%
filtered_data = new_dataset.loc[(new_dataset['Y-Kappa'] > 23) & (new_dataset['UCZAA'] > 1.7) | (new_dataset['BlowFlow'] < 1000) & (new_dataset['Y-Kappa'] < 22)]
filtered_data
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 279    11-14:00    21.27    11.383      84.165   981.920      342.858
# 283    11-18:00    20.37    10.967      99.982   998.153      302.251
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# 279        352.315         322.292  1.553       592.539  ...        73.134
# 283        344.295         305.080  1.604       471.537  ...        57.260
#
#      Lower-HeatT-3  Upper-HeatT-3   ChipMass-4   WeakLiquorF   BlackFlow-2   \
# 279        333.596         310.487      171.004       940.938      1375.202
# 283        330.293         304.958      136.358      1067.280      1346.973
#
#      WeakWashF   SteamHeatF-3   T-Top-Chips-4   SulphidityL-4
# 279     189.529         52.600         251.797            30.4
# 283     237.346         40.713         252.545            30.4
#
# [2 rows x 23 columns]

# %%
A= [998.153, 1008.98,]
data2=new_dataset[new_dataset['BlowFlow'].isin(A)]
data2
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 283    11-18:00    20.37    10.967      99.982   998.153      302.251
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# 283        344.295          305.08  1.604       471.537  ...         57.26
#
#      Lower-HeatT-3  Upper-HeatT-3   ChipMass-4   WeakLiquorF   BlackFlow-2   \
# 283        330.293         304.958      136.358       1067.28      1346.973
#
#      WeakWashF   SteamHeatF-3   T-Top-Chips-4   SulphidityL-4
# 283     237.346         40.713         252.545            30.4
#
# [1 rows x 23 columns]

# %%
new_dataset.pivot_table(index='UCZAA', values='Y-Kappa')
# Out:
#        Y-Kappa
# UCZAA
# 1.182    20.55
# 1.230    22.80
# 1.253    18.40
# 1.258    14.53
# 1.265    25.56
# ...        ...
# 1.678    24.16
# 1.689    18.50
# 1.691    23.12
# 1.710    17.81
# 1.747    21.40
#
# [101 rows x 1 columns]

# %%
#Long format of the dataset
new_dataset.melt(id_vars='UCZAA', var_name='Company/Component', value_vars=('Y-Kappa', 'BlowFlow'))
# Out:
#      UCZAA Company/Component     value
# 0    1.549           Y-Kappa    27.600
# 1    1.604           Y-Kappa    23.600
# 2    1.436           Y-Kappa    14.230
# 3    1.468           Y-Kappa    22.650
# 4    1.515           Y-Kappa    24.700
# ..     ...               ...       ...
# 277  1.429          BlowFlow  1330.104
# 278  1.488          BlowFlow  1276.082
# 279  1.523          BlowFlow  1178.252
# 280  1.451          BlowFlow  1184.119
# 281  1.523          BlowFlow  1192.879
#
# [282 rows x 3 columns]

# %%
#Renaming observation column
new_dataset.rename(columns={'Observation':'Obs'})
# Out:
#           Obs  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 1    31-01:00    27.60    16.810      79.022  1328.360      341.327
# 3    31-03:00    23.60    16.478      81.011  1334.877      213.527
# 5     1-08:00    14.23    15.350      85.518  1171.604      198.538
# 7    31-06:00    22.65    14.100      91.887  1307.852      288.989
# 9    31-08:00    24.70    13.850      96.208  1334.892      362.511
# ..        ...      ...       ...         ...       ...          ...
# 312  31-10:00    24.40    14.117      85.998  1330.104      394.234
# 317   4-16:00    17.80    16.625      78.367  1276.082      202.744
# 319  10-16:00    23.75    12.667      93.450  1178.252      276.955
# 320   9-19:00    19.80    12.558      94.352  1184.119      297.071
# 322   9-21:00    24.32    13.083      88.910  1192.879      318.006
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %%
new_dataset = new_dataset.drop('Observation', axis=1)

# %%
new_dataset = new_dataset.drop_duplicates()

# Convert dataset columns to numeric data types

new_dataset = new_dataset.apply(pd.to_numeric, errors='coerce')

q1 = new_dataset.quantile(0.25)
q3 = new_dataset.quantile(0.75)
iqr = q3 - q1
lower_bound = q1 - (1.5 * iqr)
upper_bound = q3 + (1.5 * iqr)

# Outliers Data
outliers = new_dataset[(new_dataset < lower_bound) | (new_dataset > upper_bound)]

# Data with no outliers
no_outliers = new_dataset[(new_dataset >lower_bound) & (new_dataset <upper_bound)]


no_outliers
# Out:
#      Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   T-upperExt-2   \
# 1      27.60    16.810      79.022  1328.360      341.327        351.050
# 3      23.60    16.478      81.011  1334.877      213.527        350.938
# 5      14.23    15.350      85.518  1171.604      198.538        344.014
# 7      22.65    14.100      91.887  1307.852      288.989        352.321
# 9      24.70    13.850      96.208  1334.892      362.511        352.372
# ..       ...       ...         ...       ...          ...            ...
# 290    19.90    11.333      87.405       NaN      369.383        343.515
# 292    22.00    11.858      93.199  1171.206      366.787        345.261
# 294    19.00    12.425      92.905  1272.030      316.226        345.811
# 296    20.50    13.358      97.662  1304.597      377.678        347.672
# 298    20.90    15.167      84.640  1283.706      339.440        354.803
#
#      T-lowerExt-2    UCZAA  WhiteFlow-4   AAWhiteSt-4   ...  SteamFlow-4   \
# ...

# %%
no_outliers.dropna()
# Out:
#      Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   T-upperExt-2   \
# 1      27.60    16.810      79.022  1328.360      341.327        351.050
# 3      23.60    16.478      81.011  1334.877      213.527        350.938
# 5      14.23    15.350      85.518  1171.604      198.538        344.014
# 7      22.65    14.100      91.887  1307.852      288.989        352.321
# 9      24.70    13.850      96.208  1334.892      362.511        352.372
# ..       ...       ...         ...       ...          ...            ...
# 270    21.25    14.192      91.907  1286.693      346.418        349.544
# 274    23.17    15.542      82.392  1280.501      334.242        348.771
# 276    22.70    15.517      83.008  1288.010      306.886        350.155
# 296    20.50    13.358      97.662  1304.597      377.678        347.672
# 298    20.90    15.167      84.640  1283.706      339.440        354.803
#
#      T-lowerExt-2    UCZAA  WhiteFlow-4   AAWhiteSt-4   ...  SteamFlow-4   \
# ...

# %%
#backfilling and forward filling the null values
no_outliers=no_outliers.bfill()
no_outliers=no_outliers.ffill()
no_outliers
# Out:
#      Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   T-upperExt-2   \
# 1      27.60    16.810      79.022  1328.360      341.327        351.050
# 3      23.60    16.478      81.011  1334.877      213.527        350.938
# 5      14.23    15.350      85.518  1171.604      198.538        344.014
# 7      22.65    14.100      91.887  1307.852      288.989        352.321
# 9      24.70    13.850      96.208  1334.892      362.511        352.372
# ..       ...       ...         ...       ...          ...            ...
# 290    19.90    11.333      87.405  1171.206      369.383        343.515
# 292    22.00    11.858      93.199  1171.206      366.787        345.261
# 294    19.00    12.425      92.905  1272.030      316.226        345.811
# 296    20.50    13.358      97.662  1304.597      377.678        347.672
# 298    20.90    15.167      84.640  1283.706      339.440        354.803
#
#      T-lowerExt-2    UCZAA  WhiteFlow-4   AAWhiteSt-4   ...  SteamFlow-4   \
# ...

# %%
#Checking out if there are any null values
no_outliers.isnull().sum().sum()
# Out:
# 0

# %%
#Statistics of a non-outliers dataset
no_outliers.describe()
# Out:
#           Y-Kappa    ChipRate  BF-CMratio     BlowFlow  ChipLevel4   \
# count  131.000000  131.000000  131.000000   131.000000   131.000000
# mean    20.665725   14.395328   86.630237  1247.697160   268.201771
# std      3.021990    1.496178    7.148158    53.418633    78.805733
# min     12.170000   10.833000   68.645000  1084.886000    61.783000
# 25%     18.490000   13.481000   81.164500  1198.625500   222.607500
# 50%     20.700000   14.417000   86.950000  1272.030000   275.798000
# 75%     23.185000   15.529500   92.024500  1289.225000   333.369500
# max     27.600000   16.817000  108.104000  1334.892000   419.014000
#
#        T-upperExt-2   T-lowerExt-2         UCZAA  WhiteFlow-4   AAWhiteSt-4   \
# count     131.000000      131.000000  131.000000    131.000000    131.000000
# mean      356.297397      324.671863    1.500328    595.079710      6.147214
# std         8.078226        6.332007    0.102147     68.208005      0.079816
# ...

# %%
no_outliers
# Out:
#      Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   T-upperExt-2   \
# 1      27.60    16.810      79.022  1328.360      341.327        351.050
# 3      23.60    16.478      81.011  1334.877      213.527        350.938
# 5      14.23    15.350      85.518  1171.604      198.538        344.014
# 7      22.65    14.100      91.887  1307.852      288.989        352.321
# 9      24.70    13.850      96.208  1334.892      362.511        352.372
# ..       ...       ...         ...       ...          ...            ...
# 290    19.90    11.333      87.405  1171.206      369.383        343.515
# 292    22.00    11.858      93.199  1171.206      366.787        345.261
# 294    19.00    12.425      92.905  1272.030      316.226        345.811
# 296    20.50    13.358      97.662  1304.597      377.678        347.672
# 298    20.90    15.167      84.640  1283.706      339.440        354.803
#
#      T-lowerExt-2    UCZAA  WhiteFlow-4   AAWhiteSt-4   ...  SteamFlow-4   \
# ...
